# %% [markdown]
# <a href="https://colab.research.google.com/github/Hafizuddin961/mini-project-statistic/blob/master/Statistic_1m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Package and Mount to Google Drive**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import statistics
import plotly.express as px
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Import Dataset From Google Drive**

# %%
df = pd.read_csv('/content/drive/My Drive/statistic/energy-1month.csv')
df2 = pd.read_csv('/content/drive/My Drive/statistic/energy-1month-Wh.csv')
df3 = pd.read_csv('/content/drive/My Drive/statistic/full-1month.csv')
print(df)
print(df2)
print(df3)
# Out:
#             Date&Time  Energy
# 0      12/1/2016 0:00      40
# 1      12/1/2016 0:10      30
# 2      12/1/2016 0:20      40
# 3      12/1/2016 0:30      50
# 4      12/1/2016 0:40     310
# ...               ...     ...
# 4459  11/2/2016 23:10      50
# 4460  11/2/2016 23:20      60
# 4461  11/2/2016 23:30      60
# 4462  11/2/2016 23:40      60
# 4463  11/2/2016 23:50      60
#
# [4464 rows x 2 columns]
#             Date&Time  Energy used (Wh)
# 0      12/1/2016 0:00                40
# 1      12/1/2016 0:10                30
# 2      12/1/2016 0:20                40
# 3      12/1/2016 0:30                50
# 4      12/1/2016 0:40               310
# ...               ...               ...
# 4459  11/2/2016 23:10                50
# 4460  11/2/2016 23:20                60
# 4461  11/2/2016 23:30                60
# 4462  11/2/2016 23:40                60
# 4463  11/2/2016 23:50                60
#
# [4464 rows x 2 columns]
# ...

# %% [markdown]
# # **START DATA ANALYSIS**

# %% [markdown]
# **Plot Graph from dataset**

# %%
fig = px.line(df2, x = 'Date&Time', y = 'Energy used (Wh)', title='Energy used in a houshold')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="99caaa4b-0cc5-4c68-a5d2-4e0e82b316f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99caaa4b-0cc5-4c68-a5d2-4e0e82b316f5")) {
#                     Plotly.newPlot(
#                         '99caaa4b-0cc5-4c68-a5d2-4e0e82b316f5',
# ...

# %% [markdown]
# # **SAMPLING DISTRIBUTION**

# %% [markdown]
# **Plot Graph as Population Distribution**

# %%
sns.distplot(df.Energy,label='Population Distribution')
plt.legend(loc='upper right')
x = statistics.mean(df.Energy)
y = statistics.stdev(df.Energy)
plt.ylabel('probability / frequency')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  99.90143369175627
# Standard Deviation =  117.75949756810996

# %% [markdown]
# **Doing Sampling distribution with different n**

# %% [markdown]
# Sampling Size, n = 2

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=2)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=2')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  124.25113878684672
# Standard Deviation =  278.26943807289064

# %% [markdown]
# Sampling Size, n = 5

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=5)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=5')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  213.16548944890735
# Standard Deviation =  37.312298450550486

# %% [markdown]
# Sampling Size, n = 20

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=20)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=20')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  89.98455204159048
# Standard Deviation =  86.10488352917207

# %% [markdown]
# Sampling Size, n = 100

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=100)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=100')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  62.81808832726378
# Standard Deviation =  125.43155166818657

# %% [markdown]
# Sampling Size, n = 1,000

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=1000)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=1000')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  103.94526003946245
# Standard Deviation =  121.17389736460228

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=3000)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=3000')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  99.05674989898478
# Standard Deviation =  118.14639439219961

# %% [markdown]
# Sampling Size, n = 10,000

# %%
ideal_normal = np.random.normal(df.Energy.mean(),df.Energy.std(),size=10000)
sns.distplot(ideal_normal,hist=True,color='orange',label='Sample Distribution n=10000')
plt.legend(loc='upper right')

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)
plt.ylabel('probability')
plt.xlabel('Sample Mean (Energy)')
print("Mean = ", x)
print("Standard Deviation = ", y)
# Out:
# Mean =  100.71346553373853
# Standard Deviation =  118.57988368986024

# %% [markdown]
# Comparing Sampling Distribution, n=3,000 with Population Distribution

# %%
sns.distplot(ideal_normal,hist=False,color='orange',label='Sampled(Normal Distribution)')
sns.distplot(df.Energy,hist=False,label='Population Distribution')
plt.show

x = statistics.mean(ideal_normal)
y = statistics.stdev(ideal_normal)

x1 = statistics.mean(df.Energy)
y1 = statistics.stdev(df.Energy)

print("Mean for population = ", x1)
print("Mean for sampled = ", x)
print("")
print("Standard Deviation for population = ", y1)
print("Standard Deviation for sampled = ", y)
print("")

plt.legend(loc='upper right')
plt.title('Sample distribution of energy used in a household in 1 month')
plt.ylabel('probability')
plt.xlabel('Mean (Energy in Wh)')
# Out:
# Mean for population =  99.90143369175627
# Mean for sampled =  99.05674989898478
#
# Standard Deviation for population =  117.75949756810996
# Standard Deviation for sampled =  118.14639439219961
# Text(0.5, 0, 'Mean (Energy in Wh)')

# %% [markdown]
# # **CONFIDENCE INTERVAL (CI)**

# %% [markdown]
# We then convert **normal distributed** to **standard normal distributed** form:

# %%
x = ideal_normal
x_s = (x - x.mean()) / x.std()

sns.distplot(x, color='orange').set_title('Normal Distribution')
print(x.mean())
print(x.std())
plt.show()
sns.distplot(x_s, color='orange').set_title('Standard Normal Distribution')
print(x_s.mean())
print(x_s.std())
plt.show()
# Out:
# 99.05674989898478
# 118.1267016852719
# 4.9737991503207014e-17
# 1.0

# %%
import statsmodels.stats.api as sms
import numpy as np, scipy.stats as st

sampled_3000 = ideal_normal
print("Sample mean = ", sampled_3000.mean())
print("Sample standard deviation = ", sampled_3000.std())
a = st.t.interval(0.95, len(sampled_3000)-1, 
                  loc=np.mean(sampled_3000), 
                  scale=st.sem(sampled_3000))
print("Confidence Interval (CI) are ", a, "Wh")
# Out:
# Sample mean =  99.05674989898478
# Sample standard deviation =  118.1267016852719
# Confidence Interval (CI) are  (94.82730621303162, 103.28619358493793) Wh

# %% [markdown]
# CI at 90% Siginificance level

# %%
z_interval = stats.norm.interval(alpha=0.90)
z_interval
# Out:
# (-1.6448536269514729, 1.6448536269514722)

# %% [markdown]
# CI at 95% Siginificance level

# %%
z_interval = stats.norm.interval(alpha=0.95)
z_interval
# Out:
# (-1.959963984540054, 1.959963984540054)

# %% [markdown]
# CI at 99% Siginificance level

# %%
z_interval = stats.norm.interval(alpha=0.99)
z_interval
# Out:
# (-2.5758293035489004, 2.5758293035489004)

# %% [markdown]
# # **HYPOTHESIS TESTING**

# %%
import scipy.stats as stats

kitchen = np.mean(df3.T1)
living_room = np.mean(df3.T2)

degree_sign = u"\N{DEGREE SIGN}"

print("Kitchen area temperature:",week1_mean, degree_sign + "C")
print("Living room area temperature:",week2_mean, degree_sign + "C")
# Out:
# Kitchen area temperature: 20.581179622167976 °C
# Living room area temperature: 19.792423840759 °C

# %%
from scipy.stats import ttest_1samp

energy_mean = np.mean(df.Energy)
print("Real Mean: ", energy_mean, "Wh")
tset, pval = ttest_1samp(df.Energy, 90)

print('p-values: ',pval )

if pval < 0.10:    # alpha value is 0.10 or 10%
   print("p-values < 0.1, we are rejecting null hypothesis")
else:
  print("p-values > 0.1, we are accepting null hypothesis")
# Out:
# Real Mean:  99.90143369175627 Wh
# p-values:  2.0519151379758396e-08
# p-values < 0.1, we are rejecting null hypothesis

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests

print("Mean of data = ", sampled_3000.mean())
print("Standard deviation of data = ", sampled_3000.std())

ztest ,pval = stests.ztest(sampled_3000, value=110)
print("Value of Z_test = ", ztest)

z_interval = stats.norm.interval(alpha=0.99)
print("Z_interval = ",z_interval)

if pval<0.01:
    print("since Z_test < -Z_interval or Z_test > Z_interval, we reject null hypothesis")
else:
    print("since -Z_interval < Z_test < Z_interval, we accept null hypothesis")
# Out:
# Mean of data =  99.05674989898478
# Standard deviation of data =  118.1267016852719
# Value of Z_test =  -5.0732525216549975
# Z_interval =  (-2.5758293035489004, 2.5758293035489004)
# since Z_test < -Z_interval or Z_test > Z_interval, we reject null hypothesis

# %% [markdown]
# test mean = 90 or not by 1% significant

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests

print("Mean of data = ", ideal_normal.mean())
print("Standard deviation of data = ", ideal_normal.std())

ztest ,pval = stests.ztest(ideal_normal, value=90)
print("Value of Z_test = ", ztest)

z_interval = stats.norm.interval(alpha=0.95)
print("Z_interval = ",z_interval)

if pval<0.05:
    print("since Z_test < -Z_interval or Z_test > Z_interval, we reject null hypothesis")
else:
    print("since -Z_interval < Z_test > Z_interval, we accept null hypothesis")
# Out:
# Mean of data =  99.78495983030186
# Standard deviation of data =  119.17185447004552
# Value of Z_test =  4.4964894875398675
# Z_interval =  (-1.959963984540054, 1.959963984540054)
# since Z_test < -Z_interval or Z_test > Z_interval, we reject null hypothesis

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests
from scipy.stats import ttest_rel

kitchen_mean = df3.T1.mean()
living_room_mean = df3.T2.mean()

kitchen_std = df3.T1.std()
living_room_std = df3.T2.std()

degree_sign = u"\N{DEGREE SIGN}"

print("Kitchen area Mean temperature:",kitchen_mean, degree_sign + "C")
print("Living room area Mean temperature:",living_room_mean, degree_sign + "C")
print("")

print("Kitchen area Standard Dev temperature:",kitchen_std, degree_sign + "C")
print("Living room area Standard Dev temperature:",living_room_std, degree_sign + "C")
print("")



ztest ,pval = stests.ztest(df3.T1, x2=df3.T2, value=0.75, alternative='two-sided')
print("Value of Z_test = ", ztest)


if pval<0.05:
    print("since Z_test < -Z_interval or Z_test > Z_interval, we reject null hypothesis")
else:
    print("since -Z_interval < Z_test > Z_interval, we accept null hypothesis")
# Out:
# Kitchen area Mean temperature: 20.581179622167976 °C
# Living room area Mean temperature: 19.792423840759 °C
#
# Kitchen area Standard Dev temperature: 1.577569931010288 °C
# Living room area Standard Dev temperature: 1.6476615180092027 °C
#
# Value of Z_test =  1.1351419405878593
# since -Z_interval < Z_test > Z_interval, we accept null hypothesis
